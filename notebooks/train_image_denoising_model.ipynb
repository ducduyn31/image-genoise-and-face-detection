# %%
# !pip install lightning
# !pip install lpips
# Out:
# Requirement already satisfied: lightning in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (2.1.0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from lightning) (6.0.1)
# Requirement already satisfied: fsspec<2025.0,>2021.06.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from fsspec[http]<2025.0,>2021.06.0->lightning) (2023.6.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from lightning) (0.9.0)
# Requirement already satisfied: numpy<3.0,>=1.17.2 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from lightning) (1.26.0)
# Requirement already satisfied: packaging<25.0,>=20.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from lightning) (23.2)
# Requirement already satisfied: torch<4.0,>=1.12.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from lightning) (2.1.0)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from lightning) (1.2.0)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from lightning) (4.66.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.0.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from lightning) (4.7.1)
# Requirement already satisfied: pytorch-lightning in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from lightning) (2.1.0)
# Requirement already satisfied: requests in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from fsspec[http]<2025.0,>2021.06.0->lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from fsspec[http]<2025.0,>2021.06.0->lightning) (3.8.6)
# Requirement already satisfied: filelock in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from torch<4.0,>=1.12.0->lightning) (3.9.0)
# Requirement already satisfied: sympy in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from torch<4.0,>=1.12.0->lightning) (1.11.1)
# Requirement already satisfied: networkx in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from torch<4.0,>=1.12.0->lightning) (3.1)
# Requirement already satisfied: jinja2 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from torch<4.0,>=1.12.0->lightning) (3.1.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from jinja2->torch<4.0,>=1.12.0->lightning) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from requests->fsspec[http]<2025.0,>2021.06.0->lightning) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from requests->fsspec[http]<2025.0,>2021.06.0->lightning) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from requests->fsspec[http]<2025.0,>2021.06.0->lightning) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from sympy->torch<4.0,>=1.12.0->lightning) (1.3.0)
# Collecting lpips
#   Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 952.2 kB/s eta 0:00:00
# Requirement already satisfied: torch>=0.4.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from lpips) (2.1.0)
# Requirement already satisfied: torchvision>=0.2.1 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from lpips) (0.16.0)
# Requirement already satisfied: numpy>=1.14.3 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from lpips) (1.26.0)
# Collecting scipy>=1.0.1 (from lpips)
#   Downloading scipy-1.11.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.28.1 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from lpips) (4.66.1)
# Requirement already satisfied: filelock in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from torch>=0.4.0->lpips) (3.9.0)
# Requirement already satisfied: typing-extensions in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from torch>=0.4.0->lpips) (4.7.1)
# Requirement already satisfied: sympy in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from torch>=0.4.0->lpips) (1.11.1)
# Requirement already satisfied: networkx in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from torch>=0.4.0->lpips) (3.1)
# Requirement already satisfied: jinja2 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from torch>=0.4.0->lpips) (3.1.2)
# Requirement already satisfied: fsspec in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from torch>=0.4.0->lpips) (2023.6.0)
# Requirement already satisfied: requests in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from torchvision>=0.2.1->lpips) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from torchvision>=0.2.1->lpips) (10.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from jinja2->torch>=0.4.0->lpips) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from requests->torchvision>=0.2.1->lpips) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from requests->torchvision>=0.2.1->lpips) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from requests->torchvision>=0.2.1->lpips) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from requests->torchvision>=0.2.1->lpips) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /Users/danielng/opt/anaconda3/envs/IPPRProject/lib/python3.11/site-packages (from sympy->torch>=0.4.0->lpips) (1.3.0)
# Downloading scipy-1.11.3-cp311-cp311-macosx_10_9_x86_64.whl (37.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.2/37.2 MB 12.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: scipy, lpips
# Successfully installed lpips-0.1.4 scipy-1.11.3

# %%
from custom_dataset.augmented_dataset import AugmentedDataset
from torchvision import datasets
import pathlib
from helpers.visualise import plot
import torch
import pytorch_lightning as pl

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
ROOT = pathlib.Path('../data/')

# %%
ds = AugmentedDataset(ROOT, 'train')
ds = datasets.wrap_dataset_for_transforms_v2(ds)

# %%
ds[0]
# Out:
# (<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1385>,
#  {'bbox': BoundingBoxes([[449, 330, 571, 479]], format=BoundingBoxFormat.XYXY, canvas_size=(1385, 1024))})

# %%
plot([ds[4]])

# %%
pl.seed_everything(42, workers=True)
